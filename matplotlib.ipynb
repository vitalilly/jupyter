# %% [markdown]
# # This is a heading
# this is regular text

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(-10,10,1000)
#y = np.sin(x**2)
y = x**2 + 2*x + 2

fig, ax = plt.subplots()
ax.plot (x,y)

plt.title("x² + 2x + 2")
plt.show()

# %% [markdown]
# bla bla
#     this block has writing in it!

# %% [markdown]
# # bla

# %% [markdown]
# ## bla
